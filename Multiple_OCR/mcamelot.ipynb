# %%
import math
import os
os.chdir('./')
os.getcwd()
# Out:
# 'c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR'

# %%
# !pip3 install "camelot-py[cv]"
# Out:
# ...
#   Using cached camelot_py-1.0.9-py3-none-any.whl.metadata (9.8 kB)
# ...
#   Using cached click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# ...
#   Using cached chardet-5.2.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached opencv_python_headless-4.12.0.88-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached pypdfium2-4.30.0-py3-none-win_amd64.whl.metadata (48 kB)
# ...
#   Using cached pillow-11.3.0-cp313-cp313-win_amd64.whl.metadata (9.2 kB)
# ...
#   Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# ...
#   Using cached charset_normalizer-3.4.3-cp313-cp313-win_amd64.whl.metadata (37 kB)
# ...

# %%
import camelot
camelot.__version__
# Out:
# '1.0.9'

# %%
# !pip3 install simple
# Out:
# ERROR: Could not find a version that satisfies the requirement simple (from versions: none)
# ERROR: No matching distribution found for simple

# %%
import camelot

# %%
print(lattice_tables[0].df)
# Out:
#           0            1                  2                   3
# 0  Employee   Department  Performance Score  Experience (Years)
# 1     Alice        Sales                 89                   5
# 2       Bob    Marketing                 92                   4
# 3   Charlie           HR                 85                   6
# 4     Diana  Engineering                 95                   3

# %%
type(stream_tables[0].df)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd 
pd.__version__
# Out:
# '2.3.2'
