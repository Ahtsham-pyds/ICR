# %%
# !pip3 install  python-dotenv
# !pip install importlib
# !pip3 install langchain_openai
# !pip3 install langchain_experimental
# Out:
# ...
#   Using cached pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# ...
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    ------------ --------------------------- 0.8/2.5 MB 5.3 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 5.2 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 7.1 MB/s  0:00:00
# ...
# Using cached pydantic_settings-2.11.0-py3-none-any.whl (48 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ----------------------------- ---------- 1.6/2.1 MB 7.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.6 MB/s  0:00:00
# ...
#
#    ------ ---------------------------------  3/20 [marshmallow]
#    ---------- -----------------------------  5/20 [greenlet]
# ...

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# False

# %%
# %run Mcamelot_p
# Out:
# C:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:8: SyntaxWarning: invalid escape sequence '\s'
#   lattice_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='lattice', suppress_stdout=False)
# C:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:9: SyntaxWarning: invalid escape sequence '\s'
#   stream_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='stream', suppress_stdout=False)
# C:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:15: SyntaxWarning: invalid escape sequence '\s'
#   lattice_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='lattice', suppress_stdout=False)
# C:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:16: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
#from Mcamelot_p.py import extract_table
import Mcamelot_p
#importlib.reload(Mcamelot_p)
from Mcamelot_p import extract_table
# Out:
# c:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:8: SyntaxWarning: invalid escape sequence '\s'
#   lattice_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='lattice', suppress_stdout=False)
# c:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:9: SyntaxWarning: invalid escape sequence '\s'
#   stream_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='stream', suppress_stdout=False)
# c:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:15: SyntaxWarning: invalid escape sequence '\s'
#   lattice_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='lattice', suppress_stdout=False)
# c:\Users\hahtsham\work\ICR\Multiple_OCR\Mcamelot_p.py:16: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
api_key = os.getenv("OPEN_API_KEY")
load_dotenv()
os.environ['OPENAI_API_KEY'] = os.getenv("OPEN_API_KEY")

# %%
from dotenv import dotenv_values

# %%
table = Mcamelot_p.extract_table('d')

# %%
import pandas as pd
from langchain_openai import ChatOpenAI
from langchain_experimental.agents.agent_toolkits import create_pandas_dataframe_agent

# 1. Your Camelot DataFrame



df = stream_tables[0].df
df1 = table[0].df


# 2. Initialize the LLM
llm = ChatOpenAI(temperature=0, model="gpt-4o-mini")
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hahtsham\AppData\Local\Temp\ipykernel_39056\1505203550.py:9: SyntaxWarning: invalid escape sequence '\s'
#   lattice_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='lattice', suppress_stdout=False)
# C:\Users\hahtsham\AppData\Local\Temp\ipykernel_39056\1505203550.py:10: SyntaxWarning: invalid escape sequence '\s'
#   stream_tables = camelot.read_pdf('c:\\Users\\hahtsham\\work\\ICR\\Multiple_OCR\sample_with_tables.pdf', pages='all', flavor='stream', suppress_stdout=False)

# %%
df
# Out:
#                                0            1                  2  \
# 0  Table 1: Employee Performance
# 1                       Employee   Department  Performance Score
# 2                          Alice        Sales                 89
# 3                            Bob    Marketing                 92
# 4                        Charlie           HR                 85
# 5                          Diana  Engineering                 95
#
#                     3
# 0
# 1  Experience (Years)
# 2                   5
# 3                   4
# 4                   6
# 5                   3

# %%
df1
# Out:
#           0            1                  2                   3
# 0  Employee   Department  Performance Score  Experience (Years)
# 1     Alice        Sales                 89                   5
# 2       Bob    Marketing                 92                   4
# 3   Charlie           HR                 85                   6
# 4     Diana  Engineering                 95                   3

# %%
agent = create_pandas_dataframe_agent(
            llm,
            df1,
            verbose=False,
            agent_type="openai-functions",
            allow_dangerous_code=True
        )

# 4. Ask a question
# question = "What is the average experience years for the employees?"
# response = agent.invoke({"input": question})

# print(response['output'])
while True:
    query = input("Please type your query: ")
    if query.lower() in ['q', 'quit', 'close']:
        break
    response = agent.invoke({"input": query})
    print(response['output'])

# %%
#
