# %%
from huggingface_hub import snapshot_download

download_path = snapshot_download(
    repo_id="cross-encoder/ms-marco-MiniLM-L6-v2",   # note the namespace
    revision="main"
)
print(download_path)

#cross encoder model for msmarco v2
# Out:
# Fetching 23 files: 100%|██████████| 23/23 [00:18<00:00,  1.23it/s]
# C:\Users\hahtsham\.cache\huggingface\hub\models--cross-encoder--ms-marco-MiniLM-L6-v2\snapshots\c5ee24cb16019beea0893ab7796b1df96625c6b8

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\hahtsham\\work\\ICR\\OCR'
